# %%
import pandas as pd
from pandas.tseries.offsets import DateOffset
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
import datetime as dt
from pathlib import Path
import os
from tqdm import tqdm

# %%
pathData = '/glade/u/home/demurray/External File Uploads/DOC data'
os.chdir(pathData)

#First read in NADP archived DOC data and site metadata and merge these together
ntn = pd.read_csv('ntn.csv')
ntn = ntn[['siteId', 'latitude', 'longitude']]
nadp_arch = pd.read_csv('NADP DOM data clean.csv')
nadp_arch = pd.merge(nadp_arch, ntn, on = 'siteId')
nadp_arch
# Out:
#     siteId            dateOn           dateOff  subppt  DOC_mgL_Final_UNH  \
# 0     AK02   2/21/2017 18:05   2/28/2017 18:28   8.128               0.39
# 1     AK02   3/21/2017 18:55   3/28/2017 17:50  12.192               0.49
# 2     AK02   4/18/2017 18:07   4/25/2017 18:01   8.128               0.59
# 3     AK02   5/16/2017 16:18   5/23/2017 18:23  39.116               0.48
# 4     AK02   6/13/2017 18:02   6/20/2017 17:17  78.994               0.43
# ..     ...               ...               ...     ...                ...
# 269   WY08   6/12/2018 21:15   6/18/2018 20:00  41.402               0.59
# 270   WY08   8/21/2018 14:45   8/28/2018 20:15  15.240               1.43
# 271   WY08   10/2/2018 18:45   10/9/2018 15:30  13.462               0.75
# 272   WY08  11/21/2018 16:45  11/26/2018 20:15   9.144               0.41
# 273   WY08  12/10/2018 19:15  12/18/2018 19:00   4.318               0.65
#
#      latitude  longitude
# 0     58.5139  -134.7843
# 1     58.5139  -134.7843
# 2     58.5139  -134.7843
# 3     58.5139  -134.7843
# 4     58.5139  -134.7843
# ..        ...        ...
# 269   44.9166  -110.4203
# 270   44.9166  -110.4203
# 271   44.9166  -110.4203
# 272   44.9166  -110.4203
# 273   44.9166  -110.4203
#
# [274 rows x 7 columns]

# %%
#Next read in the other DOC lat lon file and then data from the LTERs
other_lat_lon = pd.read_csv('DOC data lat lon.csv')
lter_dat = pd.read_csv('DOC_dep_HJ_Niwot_MN16_SR.csv')
lter_dat = pd.merge(lter_dat, other_lat_lon, on = 'siteId')
lter_dat =  lter_dat[['siteId', 'dateOn', 'dateOff', 'Precip_mm', 'DOC-C', 'latitude', 'longitude']]

# *** NOTE ASSUMING THAT DATE  = DATEOFF BUT HAVE TO CONFIRM W/ DAN ***
# *** ALSO NEED TO CONFIRM THE UNITS OF DOC-C HERE AND FIX HBEF COMPILATION IF SO (USED 2000-2014 FROM LIPTZIN SO SAME ISSUES APPLY) ***
# Out:
#      siteId      dateOn     dateOff  Precip_mm  DOC-C   latitude   longitude
# 0      OR10         NaN   10/5/2004      0.000    NaN  44.266640 -122.177000
# 1      OR10   10/5/2004  10/20/2004     30.734   0.55  44.266640 -122.177000
# 2      OR10  10/20/2004  10/27/2004     62.992   0.42  44.266640 -122.177000
# 3      OR10  10/27/2004   11/1/2004     31.242   0.72  44.266640 -122.177000
# 4      OR10   11/1/2004   11/9/2004     29.464   1.01  44.266640 -122.177000
# ...     ...         ...         ...        ...    ...        ...         ...
# 1780     SR    9/5/2012   9/10/2012     48.000    NaN  44.483333  -72.166667
# 1781     SR   9/10/2012   9/19/2012     20.600    NaN  44.483333  -72.166667
# 1782     SR   9/19/2012   9/25/2012     45.500    NaN  44.483333  -72.166667
# 1783     SR   9/25/2012   10/2/2012     11.700    NaN  44.483333  -72.166667
# 1784     SR   10/2/2012         NaN     42.400    NaN  44.483333  -72.166667
#
# [1785 rows x 7 columns]

# %%
#Read in Iavoriska 2016 deposition data (this is event-scale so need to groupby day and sum)
ssczo = pd.read_csv('DOCdepdata_Iavoriska2016.csv', parse_dates = ['dateOn'])
ssczo = ssczo[['dateOn', 'timeOn', 'Precip depth (mm)', 'DOC mgC/L']]
ssczo_daily = ssczo.groupby('dateOn')[['Precip depth (mm)', 'DOC mgC/L']].sum().reset_index()
ssczo_daily['dateOff'] = ssczo['dateOn']
ssczo_daily['latitude'] = 40.66598
ssczo_daily['longitude'] = -77.90376
ssczo_daily['siteId'] = 'PA15'
ssczo_daily
# Out:
#         dateOn  Precip depth (mm)  DOC mgC/L    dateOff  latitude  longitude  \
# 0   2012-05-14               34.7       2.81 2012-05-14  40.66598  -77.90376
# 1   2012-05-15               10.7       0.32 2012-05-14  40.66598  -77.90376
# 2   2012-05-21               17.3       8.92 2012-05-14  40.66598  -77.90376
# 3   2012-05-22                3.2       0.99 2012-05-15  40.66598  -77.90376
# 4   2012-05-23                1.2       2.39 2012-05-21  40.66598  -77.90376
# ..         ...                ...        ...        ...       ...        ...
# 99  2013-08-08                0.1       4.42 2013-03-31  40.66598  -77.90376
# 100 2013-08-09                4.0       3.15 2013-04-10  40.66598  -77.90376
# 101 2013-08-13                1.8       6.48 2013-04-10  40.66598  -77.90376
# 102 2013-08-19                2.8       1.60 2013-04-10  40.66598  -77.90376
# 103 2013-08-28                4.8       7.40 2013-04-12  40.66598  -77.90376
#
#     siteId
# 0     PA15
# 1     PA15
# 2     PA15
# 3     PA15
# 4     PA15
# ..     ...
# 99    PA15
# 100   PA15
# 101   PA15
# 102   PA15
# 103   PA15
#
# [104 rows x 7 columns]

# %%
#Read in TF data
tf = pd.read_csv('Wet Deposition LRHO TF DOC.csv')
tf['latitude'] = 43.108
tf['longitude'] = -70.95
tf
# Out:
#      siteId      dateOn     dateOff  Precip_mm  DOCmgCL  latitude  longitude
# 0        TF  11/18/2003  11/25/2003        8.5    0.993    43.108     -70.95
# 1        TF  11/25/2003   12/2/2003       13.6    0.739    43.108     -70.95
# 2        TF   12/2/2003   12/9/2003       24.8    0.385    43.108     -70.95
# 3        TF   12/9/2003  12/16/2003       77.1    0.308    43.108     -70.95
# 4        TF  12/16/2003  12/23/2003       11.2    0.357    43.108     -70.95
# ...     ...         ...         ...        ...      ...       ...        ...
# 1007     TF  12/22/2020  12/29/2020       30.0    0.198    43.108     -70.95
# 1008     TF  12/29/2020    1/5/2021       16.2    0.416    43.108     -70.95
# 1009     TF    1/5/2021   1/19/2021       37.1    0.371    43.108     -70.95
# 1010     TF   1/19/2021    2/1/2021        6.4    0.718    43.108     -70.95
# 1011     TF    2/1/2021    2/8/2021       33.6    0.451    43.108     -70.95
#
# [1012 rows x 7 columns]

# %%
#read in HBEF data
# *** 2000-2014 data is from Liptzin, 2014 - present is from data I had on my computer from RG22 ***
# *** NOTE ASSUMING THAT DATE  = DATEOFF BUT HAVE TO CONFIRM W/ DAN ***
# *** ALSO NEED TO CONFIRM THE UNITS OF DOC-C HERE AND FIX HBEF COMPILATION IF SO (USED 2000-2014 FROM LIPTZIN SO SAME ISSUES APPLY) ***
hbef = pd.read_csv('HBEF_DOC data.csv')
hbef['latitude'] = 43.95
hbef['longitude'] = -71.73333333
hbef = hbef[['siteId', 'dateOn', 'dateOff', 'Precip_mm', 'DOC-C', 'latitude', 'longitude']]
hbef
# Out:
#     siteId     dateOn     dateOff  Precip_mm   DOC-C  latitude  longitude
# 0     NH02        NaN  12/27/1999       24.9  0.2400     43.95 -71.733333
# 1     NH02   1/3/2000   1/10/2000       37.4  0.5300     43.95 -71.733333
# 2     NH02  1/10/2000   1/18/2000       32.3  0.4200     43.95 -71.733333
# 3     NH02  1/24/2000    2/1/2000       36.4  0.2000     43.95 -71.733333
# 4     NH02   2/1/2000   2/15/2000       50.0  0.3500     43.95 -71.733333
# ..     ...        ...         ...        ...     ...       ...        ...
# 813   NH02  3/29/2021    4/5/2021       11.5  1.1513     43.95 -71.733333
# 814   NH02  4/12/2021   4/19/2021       15.8  2.7702     43.95 -71.733333
# 815   NH02  4/19/2021   4/26/2021       18.1  2.2346     43.95 -71.733333
# 816   NH02  4/26/2021    5/3/2021       41.0  0.8595     43.95 -71.733333
# 817   NH02   5/3/2021   5/10/2021       15.1  1.1178     43.95 -71.733333
#
# [818 rows x 7 columns]

# %%
#Rename relevant columns (DOC-C, Precip_mm)
#concatenate all files together
#read in BC data
#merge with DOC data
#write master file to read into timeseries pairing

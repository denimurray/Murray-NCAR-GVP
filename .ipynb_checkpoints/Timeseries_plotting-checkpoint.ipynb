# %%
import pandas as pd
from pandas.tseries.offsets import DateOffset
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
import datetime as dt
from pathlib import Path
import os
from tqdm import tqdm
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import folium
from branca.colormap import linear
from branca.colormap import LinearColormap
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from datetime import datetime
import warnings
from scipy import stats
from folium.plugins import HeatMap
import matplotlib.cm as cm
import matplotlib.colors as colors
from cartopy.util import add_cyclic_point  # For plotting maps
import hydroeval as he
from matplotlib.colors import ListedColormap
from scipy.stats import ttest_ind
from scipy.stats import linregress
import statsmodels.api as sm

# %%
def calculate_cohens_d(modelled, observed):
    # Calculate the mean difference
    mean_diff = np.mean(modelled) - np.mean(observed)
    
    # Calculate the pooled standard deviation
    pooled_std = np.sqrt(((np.std(modelled, ddof=1) ** 2 + np.std(observed, ddof=1) ** 2) / 2))
    
    # Calculate Cohen's d
    cohens_d = mean_diff / pooled_std
    
    return cohens_d

def interpret_cohens_d(d):
    if d < 0.2:
        return "Small effect"
    elif 0.2 <= d < 0.8:
        return "Medium effect"
    else:
        return "Large effect"

# %%
#Read in cleaned timeseries of modelled and observed data
dat_all = pd.read_csv('/glade/u/home/demurray/Murray-NCAR-GVP/Data outputs/Cleaned Paired Modeled Observed Timeseries.csv', 
                      parse_dates = ['dateOnround', 'dateOffround'])
dat_all['Year'] = dat_all['dateOffround'].dt.year
dat_all
# Out:
#         Unnamed: 0 siteId  SamplingInt dateOnround dateOffround  latitude  \
# 0           354925   MT97        680.0  2013-02-27   2013-03-06  45.69200
# 1           334386   MO05        618.0  2011-11-16   2011-11-23  36.91080
# 2           334390   MO05        619.0  2011-11-23   2011-11-30  36.91080
# 3           334394   MO05        620.0  2011-11-30   2011-12-07  36.91080
# 4           334402   MO05        622.0  2011-12-14   2011-12-21  36.91080
# ...            ...    ...          ...         ...          ...       ...
# 411969      706651   OR10        156.0  2007-10-09   2007-10-16  44.26664
# 411970      706663   OR10        163.0  2007-11-27   2007-12-04  44.26664
# 411971      706559   OR10         76.0  2006-04-05   2006-04-11  44.26664
# 411972      706573   OR10         86.0  2006-06-12   2006-06-20  44.26664
# 411973      706607   OR10        116.0  2007-01-01   2007-01-09  44.26664
#
#            lon  longitude    Modelled  Observed          Variable  \
# 0       246.25  -113.9680   10.696007  18.28800  Precipitation_mm
# 1       270.00   -90.3187   87.544677  71.12000  Precipitation_mm
# 2       270.00   -90.3187   69.293174  64.69400  Precipitation_mm
# 3       270.00   -90.3187  101.827647  73.66000  Precipitation_mm
# 4       270.00   -90.3187   23.432070  36.83000  Precipitation_mm
# ...        ...        ...         ...       ...               ...
# 411969  237.50  -122.1770    5.535883   9.41324   WetDep_DOC_mgm2
# 411970  237.50  -122.1770    5.389580   7.11200   WetDep_DOC_mgm2
# 411971  237.50  -122.1770    9.497282  16.35252   WetDep_DOC_mgm2
# 411972  237.50  -122.1770   15.473949  10.28700   WetDep_DOC_mgm2
# 411973  237.50  -122.1770    3.103301   6.13156   WetDep_DOC_mgm2
#
#         Percent_Error  Precip_Percent_Error  Month  Year
# 0           70.979691             70.979691      3  2013
# 1           18.761480             18.761480     11  2011
# 2            6.637269              6.637269     11  2011
# 3           27.662082             27.662082     12  2011
# 4           57.177751             57.177751     12  2011
# ...               ...                   ...    ...   ...
# 411969      70.040433             51.784528     10  2007
# 411970      31.958326             87.558105     12  2007
# 411971      72.181058              9.471506      4  2006
# 411972      33.520527             66.433337      6  2006
# 411973      97.581886             89.806036      1  2007
#
# [411974 rows x 15 columns]

# %%
#calculate number of sites per variable
site_count = dat_all.groupby('Variable')['Modelled'].count()
site_count
# Out:
# Variable
# Precipitation_mm    132492
# WetDep_DOC_mgm2       1043
# WetDep_NH4_mgm2      51099
# WetDep_NO3_mgm2     123474
# WetDep_SO4_mgm2     103866
# Name: Modelled, dtype: int64

# %%
#Average all sites per month
dat_all_monyr_sum = dat_all.groupby(['siteId', 'Variable', 'Year', 'Month'])['Modelled', 'Observed'].sum().reset_index()
dat_all_monyr = dat_all_monyr_sum .groupby(['Variable', 'Year', 'Month'])['Modelled', 'Observed'].mean().reset_index()
dat_all_monyr['Yr-Mon'] = pd.to_datetime(dat_all_monyr[['Year', 'Month']].assign(DAY=1))

#Calculate std error
SE_mod = dat_all_monyr.groupby('Variable')[['Modelled', 'Observed']].std().reset_index()
SE_mod = SE_mod.rename(columns = {'Modelled' : 'Mod_SE', 'Observed' : 'Obs_SE'})
dat_all_monyr = pd.merge(dat_all_monyr, SE_mod, on = 'Variable')
dat_all_monyr = dat_all_monyr.loc[dat_all_monyr['Year'] != 2023,]
dat_all_monyr
# Out:
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3689639810.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dat_all_monyr_sum = dat_all.groupby(['siteId', 'Variable', 'Year', 'Month'])['Modelled', 'Observed'].sum().reset_index()
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3689639810.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dat_all_monyr = dat_all_monyr_sum .groupby(['Variable', 'Year', 'Month'])['Modelled', 'Observed'].mean().reset_index()
#               Variable  Year  Month   Modelled   Observed     Yr-Mon  \
# 0     Precipitation_mm  2002      1  39.780657  31.080238 2002-01-01
# 1     Precipitation_mm  2002      2  41.196552  33.154707 2002-02-01
# 2     Precipitation_mm  2002      3  68.065308  49.487198 2002-03-01
# 3     Precipitation_mm  2002      4  58.989627  46.849207 2002-04-01
# 4     Precipitation_mm  2002      5  81.801671  63.767714 2002-05-01
# ...                ...   ...    ...        ...        ...        ...
# 1215   WetDep_SO4_mgm2  2022      8  20.109157  11.170592 2022-08-01
# 1216   WetDep_SO4_mgm2  2022      9  15.749520   8.575988 2022-09-01
# 1217   WetDep_SO4_mgm2  2022     10  10.985052   6.414294 2022-10-01
# 1218   WetDep_SO4_mgm2  2022     11  12.886018   8.389912 2022-11-01
# 1219   WetDep_SO4_mgm2  2022     12  11.863036  10.223332 2022-12-01
#
#          Mod_SE     Obs_SE
# 0     13.747876  11.402622
# 1     13.747876  11.402622
# 2     13.747876  11.402622
# 3     13.747876  11.402622
# 4     13.747876  11.402622
# ...         ...        ...
# 1215   9.638982   9.501662
# 1216   9.638982   9.501662
# 1217   9.638982   9.501662
# 1218   9.638982   9.501662
# 1219   9.638982   9.501662
#
# [1217 rows x 8 columns]

# %%
# Plot timeseries

# Assuming 'dat_all_monyr' is your DataFrame and 'Yr-Mon' is in datetime format
for i in dat_all_monyr['Variable'].unique():
    dat_sub = dat_all_monyr.loc[dat_all_monyr['Variable'] == i]

    # Ensure 'Yr-Mon' is in datetime format
    if not pd.api.types.is_datetime64_any_dtype(dat_sub['Yr-Mon']):
        dat_sub['Yr-Mon'] = pd.to_datetime(dat_sub['Yr-Mon'])

    # Set 'Yr-Mon' as the index for time-based regression
    dat_sub.set_index('Yr-Mon', inplace=True)

    # Add a constant term for intercept
    X_modelled = sm.add_constant(dat_sub.index.astype('int64') // 10**9)  # Convert datetime to Unix timestamp
    y_modelled = dat_sub['Modelled']
    
    X_observed = sm.add_constant(dat_sub.index.astype('int64') // 10**9)  # Convert datetime to Unix timestamp
    y_observed = dat_sub['Observed']

    # Fit the models
    model_modelled = sm.OLS(y_modelled, X_modelled).fit()
    model_observed = sm.OLS(y_observed, X_observed).fit()

    # Create the regression plot
    plt.figure(figsize=(14, 6))
    #sns.set_theme(style="ticks", palette=None)
    
    sns.regplot(x=dat_sub.index.astype('int64') // 10**9, y='Modelled', data=dat_sub, lowess=False, ci=False, color='goldenrod', label='Modelled')
    sns.regplot(x=dat_sub.index.astype('int64') // 10**9, y='Observed', data=dat_sub, lowess=False, ci=False, color='cornflowerblue', label='Observed')
    
    plt.plot(dat_sub.index.astype('int64') // 10**9, model_modelled.fittedvalues, color='goldenrod', alpha=0.5)
    plt.plot(dat_sub.index.astype('int64') // 10**9, model_observed.fittedvalues, color='cornflowerblue', alpha=0.5)

    plt.plot(dat_sub.index.astype('int64') // 10**9, dat_sub.Modelled, color='goldenrod', alpha=0.5)
    plt.fill_between(dat_sub.index.astype('int64') // 10**9, dat_sub.Modelled-dat_sub['Mod_SE'], dat_sub.Modelled+dat_sub['Mod_SE'], alpha=0.1, edgecolor='goldenrod', facecolor='goldenrod')
    plt.plot(dat_sub.index.astype('int64') // 10**9, dat_sub.Observed, color='cornflowerblue', alpha=0.5)
    plt.fill_between(dat_sub.index.astype('int64') // 10**9, dat_sub.Observed-dat_sub['Obs_SE'], dat_sub.Observed+dat_sub['Obs_SE'], alpha=0.1, edgecolor='cornflowerblue', facecolor='cornflowerblue')

    plt.xlabel("")
    plt.ylabel(i)
    #plt.xlim(dat_sub.index.astype('int64').min() // 10**9, dat_sub.index.astype('int64').max() // 10**9)
    #plt.legend(loc='upper right')
    #plt.gca().set_ylim(bottom=0)

    ax = plt.gca()
    new_labels = pd.to_datetime(ax.get_xticks() * 10**9)
    ax.set_xticklabels(new_labels.strftime('%Y-%m-%d'))#, rotation=45)

    plt.savefig(f'/glade/u/home/demurray/External File Uploads/Figures/Monthly Timeseries Mod Obs {i}.jpg', format='jpg', dpi=300)  # Adjust quality as needed (0 to 100)

    plt.show()
# Out:
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3006817340.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels.strftime('%Y-%m-%d'))#, rotation=45)
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3006817340.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels.strftime('%Y-%m-%d'))#, rotation=45)
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3006817340.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels.strftime('%Y-%m-%d'))#, rotation=45)
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3006817340.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels.strftime('%Y-%m-%d'))#, rotation=45)
# /glade/derecho/scratch/demurray/tmp/ipykernel_13676/3006817340.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels.strftime('%Y-%m-%d'))#, rotation=45)

# %%
# Assuming 'dat_all_monyr' is your DataFrame and 'Yr-Mon' is in datetime format
results = []

for i in dat_all_monyr['Variable'].unique():
    dat_sub = dat_all_monyr.loc[dat_all_monyr['Variable'] == i]
    
    # Ensure 'Yr-Mon' is in datetime format
    if not pd.api.types.is_datetime64_any_dtype(dat_sub['Yr-Mon']):
        dat_sub['Yr-Mon'] = pd.to_datetime(dat_sub['Yr-Mon'])
    
    # Set 'Yr-Mon' as the index for time-based regression
    dat_sub.set_index('Yr-Mon', inplace=True)
    
    # Prepare the independent variable
    X = sm.add_constant(dat_sub.index.astype('int64') // 10**9)  # Convert datetime to Unix timestamp
    
    # Dictionary to store results for comparison
    comparison = {'Variable': i}

    # Loop over both 'Modelled' and 'Observed'
    for y_label in ['Modelled', 'Observed']:
        y = dat_sub[y_label]
        
        # Fit the model
        model = sm.OLS(y, X).fit()
        
        # Store results for comparison
        comparison[f'{y_label}_Slope'] = model.params[1]
        comparison[f'{y_label}_Intercept'] = model.params[0]
        comparison[f'{y_label}_R-squared'] = model.rsquared
    
    # Calculate percent differences
    comparison['Slope_Percent_Difference'] = 100 * (comparison['Modelled_Slope'] - comparison['Observed_Slope']) / comparison['Observed_Slope']
    comparison['Intercept_Percent_Difference'] = 100 * (comparison['Modelled_Intercept'] - comparison['Observed_Intercept']) / comparison['Observed_Intercept']
    comparison['R-squared_Percent_Difference'] = 100 * (comparison['Modelled_R-squared'] - comparison['Observed_R-squared']) / comparison['Observed_R-squared']

    # Append the comparison results to the list
    results.append(comparison)

# Convert the list of results to a DataFrame
results_df = pd.DataFrame(results)

# Display the DataFrame
results_df
results_df.to_csv('/glade/u/home/demurray/Murray-NCAR-GVP/Data outputs/Timeseries OLS stats results.csv')

# %%
#calculate max value for each variable
maxvals = dat_all.groupby('Variable')[['Modelled', 'Observed']].max()
maxvals
# Out:
#                     Modelled    Observed
# Variable
# Precipitation_mm  589.750647  558.038000
# WetDep_DOC_mgm2   114.408490  103.383000
# WetDep_NH4_mgm2    30.122501   44.963334
# WetDep_NO3_mgm2   241.054600  182.600600
# WetDep_SO4_mgm2   256.676586  273.547840

# %%
#Boxplot of modelled and observed by month
my_pal = { "Observed": "cornflowerblue", "Modelled": "goldenrod"}

for i in dat_all['Variable'].unique():
    #print(i)
    df = dat_all.loc[dat_all['Variable'] == i,]
    df_long = pd.melt(df,  id_vars=['siteId', 'dateOnround', 'dateOffround', 'latitude', 'lon', 'longitude', 'Percent_Error', 'Month', 'Variable'],
    value_vars=['Modelled', 'Observed'],var_name='Measurement')
    sns.boxplot(data = df_long, x = 'Month', y = 'value', hue = 'Measurement', fliersize=0.05, palette = my_pal)
    plt.ylabel('Value')
    plt.title(i)
    plt.ylim(-1,df_long.value.max())
    plt.legend(bbox_to_anchor=(1, 1), loc='upper right')
    plt.savefig(f'/glade/u/home/demurray/External File Uploads/Figures/Boxplot Monthly Obs Model Values CLEAN {i}.jpg', format='jpg', dpi=300)  # Adjust quality as needed (0 to 100)
    plt.show()

# %%
#Conduct a students t-test for each site and solute by month
# Assuming your DataFrame is named df and has the columns: 'Modelled', 'Observed', 'Variable', 'Month'
results = []

# Group by 'Variable' and 'Month' and apply the t-test, Cohen's d, and effect size classification
for (variable, month), group in dat_all.groupby(['Variable', 'Month']):
    t_stat, p_value = stats.ttest_ind(group['Modelled'], group['Observed'])
    d = calculate_cohens_d(group['Modelled'], group['Observed'])
    effect_size = interpret_cohens_d(d)
    
    results.append({
        'Variable': variable,
        'Month': month,
        't_stat': t_stat,
        'p_value': p_value,
        'cohens_d': d,
        'effect_size': effect_size
    })

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)
results_df.to_csv('/glade/u/home/demurray/Murray-NCAR-GVP/Data outputs/Monthly Mod Obs T Test Cohens significance.csv')
# Out:
#             Variable  Month     t_stat        p_value  cohens_d    effect_size
# 0   Precipitation_mm      1  12.878808   7.992003e-38  0.169319   Small effect
# 1   Precipitation_mm      2  13.950007   4.751870e-44  0.183728   Small effect
# 2   Precipitation_mm      3  16.228081   6.392466e-59  0.205304  Medium effect
# 3   Precipitation_mm      4  17.223808   4.425331e-66  0.223150  Medium effect
# 4   Precipitation_mm      5  17.984954   8.036083e-72  0.238415  Medium effect
# 5   Precipitation_mm      6  18.139136   5.424352e-73  0.246352  Medium effect
# 6   Precipitation_mm      7  17.942255   1.989147e-71  0.253009  Medium effect
# 7   Precipitation_mm      8  17.548829   1.999322e-68  0.249290  Medium effect
# 8   Precipitation_mm      9  11.527690   1.214893e-30  0.168715   Small effect
# 9   Precipitation_mm     10  10.356876   4.489925e-25  0.144551   Small effect
# 10  Precipitation_mm     11  10.726439   8.948713e-27  0.146738   Small effect
# 11  Precipitation_mm     12  14.191146   1.562482e-45  0.179534   Small effect
# 12   WetDep_DOC_mgm2      1  -0.926691   3.557285e-01 -0.157770   Small effect
# 13   WetDep_DOC_mgm2      2   0.307341   7.590100e-01  0.049857   Small effect
# 14   WetDep_DOC_mgm2      3  -0.677968   4.985912e-01 -0.096362   Small effect
# 15   WetDep_DOC_mgm2      4  -0.883541   3.781918e-01 -0.134739   Small effect
# 16   WetDep_DOC_mgm2      5  -1.453976   1.475855e-01 -0.208779   Small effect
# 17   WetDep_DOC_mgm2      6   0.545273   5.860679e-01  0.069815   Small effect
# 18   WetDep_DOC_mgm2      7   1.460765   1.452426e-01  0.177144   Small effect
# 19   WetDep_DOC_mgm2      8   1.719675   8.678080e-02  0.221090  Medium effect
# 20   WetDep_DOC_mgm2      9   0.555981   5.789909e-01  0.086830   Small effect
# 21   WetDep_DOC_mgm2     10  -0.110388   9.123367e-01 -0.022533   Small effect
# 22   WetDep_DOC_mgm2     11  -0.445224   6.571818e-01 -0.090881   Small effect
# 23   WetDep_DOC_mgm2     12  -2.209442   2.910801e-02 -0.406791   Small effect
# 24   WetDep_NH4_mgm2      1  -3.589112   3.335499e-04 -0.075215   Small effect
# 25   WetDep_NH4_mgm2      2  -4.975572   6.652704e-07 -0.115836   Small effect
# 26   WetDep_NH4_mgm2      3  -6.150857   8.001256e-10 -0.122956   Small effect
# 27   WetDep_NH4_mgm2      4  -6.157304   7.685869e-10 -0.123579   Small effect
# 28   WetDep_NH4_mgm2      5  -6.835038   8.733741e-12 -0.144400   Small effect
# 29   WetDep_NH4_mgm2      6  -3.417689   6.348558e-04 -0.078273   Small effect
# 30   WetDep_NH4_mgm2      7  -3.158187   1.595146e-03 -0.080141   Small effect
# 31   WetDep_NH4_mgm2      8  -1.388734   1.649567e-01 -0.032701   Small effect
# 32   WetDep_NH4_mgm2      9   0.361561   7.176900e-01  0.008232   Small effect
# 33   WetDep_NH4_mgm2     10  -2.928168   3.418387e-03 -0.062379   Small effect
# 34   WetDep_NH4_mgm2     11  -5.037991   4.803147e-07 -0.110306   Small effect
# 35   WetDep_NH4_mgm2     12  -4.999182   5.847111e-07 -0.095846   Small effect
# 36   WetDep_NO3_mgm2      1  33.501938  8.637027e-240  0.461602  Medium effect
# 37   WetDep_NO3_mgm2      2  27.364899  5.162106e-162  0.378810  Medium effect
# 38   WetDep_NO3_mgm2      3  28.652377  1.940223e-177  0.377659  Medium effect
# 39   WetDep_NO3_mgm2      4  24.443086  3.182256e-130  0.328725  Medium effect
# 40   WetDep_NO3_mgm2      5  28.913553  2.480562e-180  0.396653  Medium effect
# 41   WetDep_NO3_mgm2      6  39.044873   0.000000e+00  0.547328  Medium effect
# 42   WetDep_NO3_mgm2      7  57.417431   0.000000e+00  0.829917   Large effect
# 43   WetDep_NO3_mgm2      8  60.483884   0.000000e+00  0.878194   Large effect
# 44   WetDep_NO3_mgm2      9  48.166372   0.000000e+00  0.722247  Medium effect
# 45   WetDep_NO3_mgm2     10  37.930045  9.429018e-304  0.544672  Medium effect
# 46   WetDep_NO3_mgm2     11  30.980718  7.291394e-206  0.438792  Medium effect
# 47   WetDep_NO3_mgm2     12  35.286437  1.126862e-265  0.465283  Medium effect
# 48   WetDep_SO4_mgm2      1   7.583680   3.523048e-14  0.113392   Small effect
# 49   WetDep_SO4_mgm2      2   7.511876   6.100362e-14  0.111838   Small effect
# 50   WetDep_SO4_mgm2      3   6.801410   1.065256e-11  0.096177   Small effect
# 51   WetDep_SO4_mgm2      4   5.000894   5.757692e-07  0.072806   Small effect
# 52   WetDep_SO4_mgm2      5   8.309148   1.032480e-16  0.124566   Small effect
# 53   WetDep_SO4_mgm2      6  10.280979   1.020662e-24  0.160660   Small effect
# 54   WetDep_SO4_mgm2      7  14.099058   7.232719e-45  0.225146  Medium effect
# 55   WetDep_SO4_mgm2      8  17.908375   4.796740e-71  0.279307  Medium effect
# 56   WetDep_SO4_mgm2      9  19.057041   4.745925e-80  0.306535  Medium effect
# 57   WetDep_SO4_mgm2     10  13.203061   1.337781e-39  0.205571  Medium effect
# 58   WetDep_SO4_mgm2     11   6.195442   5.953232e-10  0.097569   Small effect
# 59   WetDep_SO4_mgm2     12   3.675378   2.381679e-04  0.054012   Small effect

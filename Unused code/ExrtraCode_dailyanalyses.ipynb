# %%
#################### WET DEP Carbon ############################################3
#DOC wet = pom, soa (SFWET) **Carbon fields may have to play around with which ones are included if overestimating (eg pom or the BCPH/OCPH)
nc_daily['DOC_wet_sum'] = (nc_daily['pom_a1SFWET']  + nc_daily['pom_a4SFWET']  + nc_daily['pom_c1SFWET'] 
+ nc_daily['pom_c4SFWET']  + nc_daily['soa1_a1SFWET'] + nc_daily['soa1_a2SFWET'] + nc_daily['soa1_a2SFWET'] 
+ nc_daily['soa1_c2SFWET'] + nc_daily['soa2_a1SFWET'] + nc_daily['soa2_a2SFWET'] + nc_daily['soa2_c2SFWET'] 
+ nc_daily['soa3_a1SFWET'] + nc_daily['soa3_a2SFWET'] + nc_daily['soa3_a2SFWET'] + nc_daily['soa3_c2SFWET'] 
+ nc_daily['soa4_a1SFWET'] + nc_daily['soa4_a2SFWET'] + nc_daily['soa4_a2SFWET'] + nc_daily['soa4_c2SFWET'] 
+ nc_daily['soa5_a1SFWET'] + nc_daily['soa5_a2SFWET'] + nc_daily['soa5_a2SFWET'] + nc_daily['soa5_c2SFWET']) * -1

# %%
#################### DRY DEP VARS ############################################3
#Dust mass = dst
nc_daily['Dust_mass_sum'] = nc_daily['dst_a1DDF'] + nc_daily['dst_a2DDF'] + nc_daily['dst_a3DDF'] + nc_daily['dst_c1DDF'] + nc_daily['dst_c2DDF'] + nc_daily['dst_c3DDF']

#OC dry = pom, soa (DDF)
nc_daily['DOC_dry_sum'] = nc_daily['pom_a1DDF']  + nc_daily['pom_a4DDF']  + nc_daily['pom_c1DDF'] 
+ nc_daily['pom_c4DDF']  + nc_daily['soa1_a1DDF'] + nc_daily['soa1_a2DDF'] + nc_daily['soa1_a2DDF'] 
+ nc_daily['soa1_c2DDF'] + nc_daily['soa2_a1DDF'] + nc_daily['soa2_a2DDF'] + nc_daily['soa2_c2DDF'] 
+ nc_daily['soa3_a1DDF'] + nc_daily['soa3_a2DDF'] + nc_daily['soa3_a2DDF'] + nc_daily['soa3_c2DDF'] 
+ nc_daily['soa4_a1DDF'] + nc_daily['soa4_a2DDF'] + nc_daily['soa4_a2DDF'] + nc_daily['soa4_c2DDF'] 
+ nc_daily['soa5_a1DDF'] + nc_daily['soa5_a2DDF'] + nc_daily['soa5_a2DDF'] + nc_daily['soa5_c2DDF']

#Black carbon dry = bc
nc_daily['BC_dry_sum'] = nc_daily['bc_a1DDF'] + nc_daily['bc_c1DDF'] + nc_daily['bc_a4DDF'] + nc_daily['bc_c4DDF']

#NH4+NO3 dry
nc_daily['NH4NO3_dry_sum'] = nc_daily['DF_NH4'] + nc_daily['DF_NO3']

# %%
import pandas as pd
from pandas.tseries.offsets import DateOffset
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs                 # For plotting maps
import cartopy.feature as cfeature         # For plotting maps
import numpy as np
from scipy.interpolate import griddata
import datetime
from pathlib import Path
import os

# %%
#Define Functions
# Find nearest index
def find_index(array, x):
    if array.ndim == 1:
        idx = np.argmin(np.abs(array - x))
    elif array.ndim == 2:
        idx = np.unravel_index(np.argmin(np.abs(array - x)), array.shape)
    else:
        raise ValueError("Unsupported array dimensions for find_index function.")
    return idx

#abline
def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '--')

#assign season to xarray
month_to_season = {
    12: "Winter",
    1: "Winter",
    2: "Winter",
    3: "Spring",
    4: "Spring",
    5: "Spring",
    6: "Summer",
    7: "Summer",
    8: "Summer",
    9: "Autumn",
    10: "Autumn",
    11: "Autumn",
}
vectorized_assign_season = np.vectorize(lambda month: month_to_season[month])

# %%
# Read in GPS locations of NADP sites
pathData = '/glade/u/home/demurray/External File Uploads'
os.chdir(pathData)
ntn = pd.read_csv('ntn.csv')
ntn_chem = pd.read_csv('NTN-ALL-Weekly 2000_2022.csv', parse_dates = ['dateOn', 'dateOff']) #ignore warning

#replace all negative numbers with np.nan and assign year month as indvl columns
ntn_chem[ntn_chem.select_dtypes(include='number') < 0] = np.nan
ntn_chem['yrmonth'] = ntn_chem['yrmonth'].astype(str)
ntn_chem['year'] = ntn_chem['yrmonth'].str[:4]
ntn_chem['month'] = ntn_chem['yrmonth'].str[4:]

# %%
# Select just relevant columns from the ntn_chem csv and clean up the data
ntn_SO4 = ntn_chem[['siteId', 'yrmonth', 'year', 'month', 'SO4', 'ppt', 'svol']] #SO4 = mg/L and ppt = mm, svol = mL
ntn_SO4 = ntn_SO4.rename(columns = {'SO4':'SO4_mgL', 'ppt':'ppt_mm', 'svol':'svol_mL'}) #assign units
ntn_SO4['SO4_kgm2_ppt'] = (ntn_SO4['SO4_mgL'] * ntn_SO4['ppt_mm'])/1000000 #this is scaled to precip volume assuming 1mm = 1L/m2
#ntn_SO4['SO4_kgm2_svol'] = (ntn_SO4['SO4_mgL'] * ((ntn_SO4['svol_mL']/1000)/0.06789))/ 1000000
ntn_SO4.head(10)
# Out:
#   siteId yrmonth  year month  SO4_mgL  ppt_mm  svol_mL  SO4_kgm2_ppt
# 0   AB32  201609  2016    09      NaN   0.762     74.8           NaN
# 1   AB32  201609  2016    09      NaN   0.508      7.8           NaN
# 2   AB32  201610  2016    10    0.382  18.034   1207.1  6.888988e-06
# 3   AB32  201610  2016    10      NaN  10.160    673.5           NaN
# 4   AB32  201610  2016    10      NaN  13.208    900.1           NaN
# 5   AB32  201610  2016    10    1.108   3.556    244.0  3.940048e-06
# 6   AB32  201610  2016    10    1.398   4.572    262.4  6.391656e-06
# 7   AB32  201611  2016    11    0.584   1.524    114.4  8.900160e-07
# 8   AB32  201611  2016    11    0.558   0.254     16.7  1.417320e-07
# 9   AB32  201611  2016    11    1.323   0.508     42.5  6.720840e-07

# %%
#then group by year month and average vals.
ntn_SO4_mon = ntn_SO4.groupby(['siteId', 'yrmonth', 'year', 'month'])[['SO4_kgm2_ppt']].mean().reset_index()
ntn_SO4_mon[ntn_SO4_mon.select_dtypes(include='number') == 0] = np.nan
ntn_SO4_mon.head(10)
# Out:
#   siteId yrmonth  year month  SO4_kgm2_ppt
# 0   AB32  201609  2016    09           NaN
# 1   AB32  201610  2016    10  5.740231e-06
# 2   AB32  201611  2016    11  9.433560e-07
# 3   AB32  201612  2016    12  1.475063e-06
# 4   AB32  201701  2017    01  7.452360e-07
# 5   AB32  201702  2017    02           NaN
# 6   AB32  201703  2017    03  1.237577e-05
# 7   AB32  201704  2017    04  1.045388e-05
# 8   AB32  201705  2017    05  1.484173e-05
# 9   AB32  201706  2017    06  2.725251e-05

# %%
#Assign some other variables:
ntn = ntn.rename(columns = {'latitude' : 'lat', 'longitude': 'lon_NADP'})
ntn_info = ntn[['siteId', 'lat', 'lon_NADP']]
ntn_SO4_mon = pd.merge(ntn_SO4_mon, ntn_info, on = ['siteId'])
ntn_SO4_mon['lon'] = 360-(ntn['lon_NADP']*-1)
ntn_SO4_mon['time'] = pd.to_datetime(ntn_SO4_mon[['year', 'month']].assign(day=15))
ntn_SO4_mon.head(10)
# Out:
#   siteId yrmonth  year month  SO4_kgm2_ppt      lat  lon_NADP       lon  \
# 0   AB32  201609  2016    09           NaN  57.1894 -111.6406  248.3594
# 1   AB32  201610  2016    10  5.740231e-06  57.1894 -111.6406  248.8273
# 2   AB32  201611  2016    11  9.433560e-07  57.1894 -111.6406  248.9614
# 3   AB32  201612  2016    12  1.475063e-06  57.1894 -111.6406  212.5090
# 4   AB32  201701  2017    01  7.452360e-07  57.1894 -111.6406  225.2157
# 5   AB32  201702  2017    02           NaN  57.1894 -111.6406  211.0324
# 6   AB32  201703  2017    03  1.237577e-05  57.1894 -111.6406  210.3931
# 7   AB32  201704  2017    04  1.045388e-05  57.1894 -111.6406  203.3336
# 8   AB32  201705  2017    05  1.484173e-05  57.1894 -111.6406  272.7578
# 9   AB32  201706  2017    06  2.725251e-05  57.1894 -111.6406  274.0301
#
#         time
# 0 2016-09-15
# 1 2016-10-15
# 2 2016-11-15
# 3 2016-12-15
# 4 2017-01-15
# 5 2017-02-15
# 6 2017-03-15
# 7 2017-04-15
# 8 2017-05-15
# 9 2017-06-15

# %%
# Read in all netCDF SO4 files together
result_dir = Path('/glade/campaign/acom/acom-climate/UTLS/shawnh/archive/FCnudged_f09.mam.mar27.2000_2021.001/atm/proc/tseries/month_1')
so4_files_to_open = "FCnudged_f09.mam.mar27.2000_2021.001.cam.h0.so4_*SFWET.200101-202212.nc"
nc_load_so4 = xr.open_mfdataset(str(result_dir/so4_files_to_open),combine='nested')
nc_load_so4 #lat = 192, lon = 288, time = 264 (12 months * 22 years = 264)
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 192, lon: 288, lev: 32, ilev: 33, time: 264, nbnd: 2)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon           (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time          (time) datetime64[ns] 2001-02-01 2001-03-01 ... 2023-01-01
# Dimensions without coordinates: nbnd
# Data variables: (12/31)
#     gw            (lat) float64 dask.array<chunksize=(192,), meta=np.ndarray>
#     hyam          (lev) float64 dask.array<chunksize=(32,), meta=np.ndarray>
#     hybm          (lev) float64 dask.array<chunksize=(32,), meta=np.ndarray>
#     P0            float64 1e+05
#     hyai          (ilev) float64 dask.array<chunksize=(33,), meta=np.ndarray>
#     hybi          (ilev) float64 dask.array<chunksize=(33,), meta=np.ndarray>
#     ...            ...
#     so4_a1SFWET   (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_a2SFWET   (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_a3SFWET   (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_c1SFWET   (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_c2SFWET   (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_c3SFWET   (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              FCnudged_f09.mam.mar27.2000_2021.001
#     logname:           tilmes
#     host:              cheyenne3
#     initial_file:      /glade/work/tilmes/inputdata/init/carma/f.e21.FWHISTBg...
#     topography_file:   /glade/p/cesmdata/cseg/inputdata/atm/cam/topo/fv_0.9x1...
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  month_1

# %%
#Do unit conversions now:
# Select variables from the results_dataset
var_sel_so4 = nc_load_so4[['so4_a1SFWET', 'so4_a2SFWET', 'so4_a3SFWET', 'so4_c1SFWET',
                              'so4_c2SFWET', 'so4_c3SFWET']]  # extract these variables

# Reconfigure the time variable
time = var_sel_so4['time']
var_sel_so4['time'] = pd.to_datetime(time.values,format='%Y-%m-%dT%H:%M:%S')+DateOffset(months=-1,days=+14)

#Conversions
conversions = 2.628e6*-1 #seconds to months and Convert to positive values, negative because its a flux TO surface
var_sel_so4 = var_sel_so4.apply(lambda x: x * conversions if x.name in ['so4_a1SFWET', 'so4_a2SFWET', 'so4_a3SFWET', 
                                                                        'so4_c1SFWET', 'so4_c2SFWET', 'so4_c3SFWET'] else x)

#Create new variables to represent the sum of the a's, c's, and total
var_sel_so4['SO4_a_sum'] = var_sel_so4['so4_a1SFWET'] + var_sel_so4['so4_a2SFWET'] + var_sel_so4['so4_a3SFWET']
var_sel_so4['SO4_c_sum'] = var_sel_so4['so4_c1SFWET'] + var_sel_so4['so4_c2SFWET'] + var_sel_so4['so4_c3SFWET']
var_sel_so4['SO4_total'] = var_sel_so4['SO4_a_sum'] + var_sel_so4['SO4_c_sum']
seasons = vectorized_assign_season(var_sel_so4['time.month'].values)
var_sel_so4['Season'] = xr.DataArray(seasons, coords=[var_sel_so4['time']], dims=['time'])
var_sel_so4
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 192, lon: 288, time: 264)
# Coordinates:
#   * lat          (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon          (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time         (time) datetime64[ns] 2001-01-15 2001-02-15 ... 2022-12-15
# Data variables:
#     so4_a1SFWET  (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_a2SFWET  (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_a3SFWET  (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_c1SFWET  (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_c2SFWET  (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     so4_c3SFWET  (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     SO4_a_sum    (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     SO4_c_sum    (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     SO4_total    (time, lat, lon) float32 dask.array<chunksize=(264, 192, 288), meta=np.ndarray>
#     Season       (time) <U6 'Winter' 'Winter' 'Spring' ... 'Autumn' 'Winter'

# %%
#calculate mean of each season for ntn_SO4_mon and var_sel_SO4

#xarray
var_sel_seas = var_sel_so4['SO4_total'].groupby(var_sel_so4.Season).mean(dim='time')
#var_sel_seas

#dataframe
ntn_SO4['month'] = pd.to_numeric(ntn_SO4['month'], errors='coerce')
ntn_SO4['Season'] = ntn_SO4['month'].map(month_to_season)
ntn_SO4_seas = ntn_SO4.groupby(['siteId', 'Season'])[['SO4_kgm2_ppt']].mean().reset_index()
ntn_SO4_seas = pd.merge(ntn,ntn_SO4_seas, on= 'siteId')
#ntn_SO4_seas
# Out:
#      network siteId                 siteName status  startDate    stopDate  \
# 0        NTN   AB32              Fort Mackay      A  9/13/2016         NaN
# 1        NTN   AB32              Fort Mackay      A  9/13/2016         NaN
# 2        NTN   AB32              Fort Mackay      A  9/13/2016         NaN
# 3        NTN   AB32              Fort Mackay      A  9/13/2016         NaN
# 4        NTN   AB34           Stony Mountain      A  4/24/2019         NaN
# ...      ...    ...                      ...    ...        ...         ...
# 1346     NTN   WI99              Lake Geneva      I   6/5/1984  12/31/2013
# 1347     NTN   WV99  Canaan Valley Institute      I  8/27/2019   9/20/2021
# 1348     NTN   WV99  Canaan Valley Institute      I  8/27/2019   9/20/2021
# 1349     NTN   WV99  Canaan Valley Institute      I  8/27/2019   9/20/2021
# 1350     NTN   WV99  Canaan Valley Institute      I  8/27/2019   9/20/2021
#
#         county state      lat  lon_NADP  elevation      stateName siteClass  \
# 0          NaN    AB  57.1894 -111.6406      265.0        Alberta         I
# 1          NaN    AB  57.1894 -111.6406      265.0        Alberta         I
# 2          NaN    AB  57.1894 -111.6406      265.0        Alberta         I
# 3          NaN    AB  57.1894 -111.6406      265.0        Alberta         I
# 4          NaN    AB  55.6214 -111.1727      673.0        Alberta         I
# ...        ...   ...      ...       ...        ...            ...       ...
# 1346  Walworth    WI  42.5792  -88.5006      288.0      Wisconsin         R
# 1347    Tucker    WV  39.1191  -79.4522      988.0  West Virginia         I
# 1348    Tucker    WV  39.1191  -79.4522      988.0  West Virginia         I
# 1349    Tucker    WV  39.1191  -79.4522      988.0  West Virginia         I
# 1350    Tucker    WV  39.1191  -79.4522      988.0  West Virginia         I
#
#       Season  SO4_kgm2_ppt
# 0     Autumn      0.000004
# 1     Spring      0.000009
# 2     Summer      0.000011
# 3     Winter      0.000002
# 4     Autumn      0.000002
# ...      ...           ...
# 1346  Winter      0.000013
# 1347  Autumn      0.000004
# 1348  Spring      0.000011
# 1349  Summer      0.000014
# 1350  Winter      0.000010
#
# [1351 rows x 15 columns]

# %%
#make a map setup:
var_sel = var_sel_seas
print(var_sel)

#select the variable at a specific time 
var_srf = var_sel.isel(Season=3) #'Autumn', 'Spring', 'Summer', 'Winter' = 0,1,2,3
print(var_srf.shape)

#extract grid variables
lat = var_sel.coords['lat']
lon = var_sel.coords['lon']
print(lat.shape)
# Out:
# <xarray.DataArray 'SO4_total' (Season: 4, lat: 192, lon: 288)>
# dask.array<transpose, shape=(4, 192, 288), dtype=float32, chunksize=(4, 192, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * Season   (Season) object 'Autumn' 'Spring' 'Summer' 'Winter'
# (192, 288)
# (192,)

# %%
#make a map: plot
plt.figure(figsize=(20,8))

#Define projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Zoom to a region
#longitude limits in degrees, latitude limits in degrees
ax.set_xlim(-170,-40)
ax.set_ylim(15,75)

#define contour levels
clev = np.arange(0, 0.0002, 0.00000005)

#plot the data
cmap = plt.cm.get_cmap('Spectral_r')
contour = plt.contourf(lon,lat,var_srf,clev, cmap=cmap,extend='both')

# add coastlines
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS)

#add lat lon grids
gl = ax.gridlines(draw_labels=True, color='grey', alpha=0.8, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

# Titles
plt.title("CAM-chem SO4, Average Winter 2001-2022",fontsize=18)

# y-axis
ax.text(-0.04, 0.5, 'Latitude', va='bottom', ha='center',
        rotation='vertical', rotation_mode='anchor',
        transform=ax.transAxes)
# x-axis
ax.text(0.5, -0.08, 'Longitude', va='bottom', ha='center',
        rotation='horizontal', rotation_mode='anchor',
        transform=ax.transAxes)
# legend
#ax.text(1.15, 0.5, 'SO4 (kg/m2/month)', va='bottom', ha='center',
#        rotation='vertical', rotation_mode='anchor',
#        transform=ax.transAxes)

#add color bar
cbar = plt.colorbar(contour, pad=0.05)  # Adjust pad value as needed
cbar.set_label('SO4 (kg/m2/month)', labelpad=15)  # Adjust labelpad value as needed

#Overlay points
ntn_so4_t0 = ntn_SO4_seas.loc[ntn_SO4_seas.Season == 'Winter',]
ntn_so4_t0 = ntn_so4_t0[['siteId', 'SO4_kgm2_ppt', 'lat', 'lon_NADP', 'Season']]
ntn_so4_t0.dropna(inplace = True)

#first we need to define our observational data into an array
latpt = np.array(ntn_so4_t0['lat'])
lonpt = np.array(ntn_so4_t0['lon_NADP'])
lonpt = lonpt + 360
obs_so4 = np.array(ntn_so4_t0['SO4_kgm2_ppt'])

#this is needed for convert the observation to the position on the basemap color gradient defined above
norm = plt.Normalize(vmin=clev.min(), vmax=clev.max())
colors = cmap(norm(obs_so4))

ax.scatter(lonpt, latpt, c=colors, marker='o', s=50, edgecolors="black", linewidths=1, transform=ccrs.PlateCarree())

plt.show()
# Out:
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
# subset the xarray for cells that correspond with the lat long of the ntn sites
# Iterate over the lat/long coordinates in the CSV file and subset xarray
subset_list = []
for index, row in ntn.iterrows():
    lat = row['lat']
    lon = 360-(row['lon_NADP']*-1)   # longitude is positive and based on 360 degrees.
    lat_idx = find_index(var_sel_so4['lat'].values, lat)   # right now we are doing a 'find nearest' calculation, should probably interpolate across grid cell and have exact coordinates represented?
    lon_idx = find_index(var_sel_so4['lon'].values, lon)
    subset = var_sel_so4.isel(lat=lat_idx, lon=lon_idx)
    subset['siteId'] = row['siteId']  # Add 'siteId' as a new coordinate/index
    subset = subset.assign_coords(siteId=row['siteId'])
    subset_list.append(subset)

# Concatenate the list of subsets into a new xarray dataset
result_dataset = xr.concat(subset_list, dim='siteId')
result_dataset
# Out:
# <xarray.Dataset>
# Dimensions:      (siteId: 391, time: 264)
# Coordinates:
#     lat          (siteId) float64 57.02 56.07 57.02 65.5 ... 42.88 39.11 40.99
#     lon          (siteId) float64 248.8 248.8 248.8 212.5 ... 271.2 280.0 253.8
#   * time         (time) datetime64[ns] 2001-01-15 2001-02-15 ... 2022-12-15
#   * siteId       (siteId) <U4 'AB32' 'AB34' 'AB36' ... 'WI99' 'WV99' 'WY96'
# Data variables:
#     so4_a1SFWET  (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     so4_a2SFWET  (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     so4_a3SFWET  (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     so4_c1SFWET  (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     so4_c2SFWET  (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     so4_c3SFWET  (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     SO4_a_sum    (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     SO4_c_sum    (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     SO4_total    (siteId, time) float32 dask.array<chunksize=(1, 264), meta=np.ndarray>
#     Season       (siteId, time) <U6 'Winter' 'Winter' ... 'Autumn' 'Winter'

# %%
#Select and extract the location
site_sel = 'CO98'
subset_nc = result_dataset.sel(siteId=site_sel) #subset site from xarray

#plot the NADP data
ntn_SO4_sub = ntn_SO4_mon.loc[ntn_SO4_mon.siteId == site_sel,] #subset for CA96 from NADP data
ntn_SO4_sub = ntn_SO4_sub.loc[ntn_SO4_sub.time >= "2001-01-15",]

# Plot
fig, (ax1) = plt.subplots(1, 1, figsize=(20, 8), sharey=False, sharex = True)
ax1.plot(time, subset_nc['SO4_total'], label='Cam Chem SO4 flux kg/m2/month')
ax1.plot(time, ntn_SO4_sub['SO4_kgm2_ppt'], label='SO4 flux NADP kg/m2/month BY PRECIP', color = "orange") #precip seems more accurate
#ax2.plot(time, ntn_SO4_CA96['SO4_kgm2_svol'], label='SO4 flux NADP kg/m2/month BY VOLUME')
plt.xlabel('time')
plt.ylabel('Average Flux (kg/m2/month)')
plt.title(site_sel)
ax1.legend()
#ax2.legend()
plt.show()

#This looks pretty good considering that:
# a) we are comparing at a monthly average scale (e.g., not daily data)
# b) using a large grid cell size and not interpolating across the grid (just using find nearest function at global model res)
# c) the overall TREND looks good, but the magnitude is higher from the CAM CHEM outputs
# d) the means are calculated differently, the CESM model is presumably a mean based off of daily outputs 
        # and NADP is average of cumulative weekly samples
# e) Cam-Chem delineates 1 month as exactly days 1-30 while NADP month is the approximate month due to when weekly samples were collected

# %%
# Extract relevant data variables from results dataset for eventual conversion to dataframe.
so4_mod = result_dataset['SO4_total']
so4_mod_df = so4_mod.to_dataframe().reset_index()
so4_mod_obs = pd.merge(so4_mod_df, ntn_SO4_mon, on = ['siteId', 'time'])
so4_mod_obs = so4_mod_obs[['siteId', 'time', 'yrmonth','month','year', 'SO4_kgm2_ppt', 'SO4_total']]
so4_mod_obs['month'] = pd.to_numeric(so4_mod_obs['month'], errors='coerce')
so4_mod_obs['Season'] = so4_mod_obs['month'].map(month_to_season)
so4_mod_obs
# Out:
#       siteId       time yrmonth  month  year  SO4_kgm2_ppt  SO4_total  Season
# 0       AB32 2016-09-15  201609      9  2016           NaN   0.000013  Autumn
# 1       AB32 2016-10-15  201610     10  2016  5.740231e-06   0.000019  Autumn
# 2       AB32 2016-11-15  201611     11  2016  9.433560e-07   0.000003  Autumn
# 3       AB32 2016-12-15  201612     12  2016  1.475063e-06   0.000005  Winter
# 4       AB32 2017-01-15  201701      1  2017  7.452360e-07   0.000002  Winter
# ...      ...        ...     ...    ...   ...           ...        ...     ...
# 66279   WV99 2021-05-15  202105      5  2021  1.321274e-05   0.000057  Spring
# 66280   WV99 2021-06-15  202106      6  2021  1.722281e-05   0.000065  Summer
# 66281   WV99 2021-07-15  202107      7  2021  6.365850e-05   0.000059  Summer
# 66282   WV99 2021-08-15  202108      8  2021  1.418488e-05   0.000086  Summer
# 66283   WV99 2021-09-15  202109      9  2021  4.519507e-06   0.000052  Autumn
#
# [66284 rows x 8 columns]

# %%
# Iterate over months
for season in range(1, 13):  # Assuming month is in the range 1 to 12
    # Select data for the current month
    month_data = df[df['month'] == str(month)]

    # Create scatter plot
    plt.scatter(month_data['SO4_total'], month_data['SO4_kgm2_ppt'], alpha=0.4)
    plt.title(f'Scatter plot for Month {month}')
    plt.xlabel('SO4_total')
    plt.ylabel('SO4_kgm2_ppt')
    plt.show()

# %%
data:image/png;base64,...
